# %% [markdown]
# # Should I stay in U.S ? Let's anylisis the unemploy rate

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import datetime

unrate=pd.read_csv("UNRATE.csv")
unrate['DATE']=pd.to_datetime(unrate['DATE'])
plt.plot(unrate['DATE'],unrate['UNRATE'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 首先，请减少数据量，用当年的月平均值代替12个月的数据
#    提示，可以利用pandas里的loc，tolist 方法
#    利用numpy里的mean()方法求每年12个月的平均值

# %% [markdown]
# ## 先计算一年的，以1949为例

# %%
print(unrate.head(24))
print("Just print 1949")
unrate1949=unrate.loc[12:23]
print(unrate1949)
# Out:
#          DATE  UNRATE
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5
# 5  1948-06-01     3.6
# 6  1948-07-01     3.6
# 7  1948-08-01     3.9
# 8  1948-09-01     3.8
# 9  1948-10-01     3.7
# 10 1948-11-01     3.8
# 11 1948-12-01     4.0
# 12 1949-01-01     4.3
# 13 1949-02-01     4.7
# 14 1949-03-01     5.0
# 15 1949-04-01     5.3
# 16 1949-05-01     6.1
# 17 1949-06-01     6.2
# 18 1949-07-01     6.7
# 19 1949-08-01     6.8
# 20 1949-09-01     6.6
# 21 1949-10-01     7.9
# 22 1949-11-01     6.4
# 23 1949-12-01     6.6
# Just print 1949
#          DATE  UNRATE
# 12 1949-01-01     4.3
# 13 1949-02-01     4.7
# 14 1949-03-01     5.0
# 15 1949-04-01     5.3
# 16 1949-05-01     6.1
# 17 1949-06-01     6.2
# 18 1949-07-01     6.7
# 19 1949-08-01     6.8
# 20 1949-09-01     6.6
# 21 1949-10-01     7.9
# 22 1949-11-01     6.4
# 23 1949-12-01     6.6

# %% [markdown]
# ## 将12月的失业率转换为向量
# 提示：利用numpy的array方法

# %%
import numpy as ny

vector1949=ny.array(unrate1949['UNRATE'])
print(vector1949)
# Out:
# [ 4.3  4.7  5.   5.3  6.1  6.2  6.7  6.8  6.6  7.9  6.4  6.6]

# %% [markdown]
# ## 然后求12个月的平均值
# 提示：利用numpy的mean()函数

# %%
mean1949=vector1949.mean()
print(mean1949)
# Out:
# 6.05

# %% [markdown]
# # 好，现在请将1948年到2017年的年平均值写到列表中名称为ur70years
#
# 提示：列表存储70年的年代数字
# 1.range(0,70) 生成 0到70的序列
# 2.用for循环遍历
# 3.用ur70years列表存储70年的失业率
# 4.用uy70years列表存储70年的年代数字
# 5.用ny.array 将当年的12个月转化为向量，名称为vector12month
# 6.用mean()求平均
# 7.用append 加入ur70years,uy70years

# %%
ur70years=[]
uy70years=[]

for idx in range(0,70):
    year=1948+idx
    unreate12month=unrate.loc[idx*12:idx*12+11]
    vector12month=ny.array(unreate12month['UNRATE'])
    rate12monthmean=vector12month.mean()
    uy70years.append(year)
    ur70years.append(rate12monthmean)

# %% [markdown]
# # 请用matplotlib画出 unrate70years的曲线图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(uy70years,ur70years)
plt.xticks(rotation=90)
plt.show()

print(uy70years)
print(ur70years)
# Out:
# [1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# [3.75, 6.0499999999999998, 5.208333333333333, 3.2833333333333332, 3.0250000000000004, 2.9250000000000003, 5.5916666666666659, 4.3666666666666671, 4.125, 4.2999999999999998, 6.8416666666666677, 5.4500000000000002, 5.541666666666667, 6.6916666666666664, 5.5666666666666673, 5.6416666666666666, 5.1583333333333341, 4.5083333333333337, 3.7916666666666665, 3.8416666666666663, 3.5583333333333331, 3.4916666666666667, 4.9833333333333334, 5.9500000000000002, 5.6000000000000005, 4.8583333333333334, 5.6416666666666666, 8.4749999999999996, 7.6999999999999993, 7.0500000000000007, 6.0666666666666664, 5.8500000000000005, 7.1750000000000007, 7.6166666666666671, 9.7083333333333339, 9.5999999999999996, 7.5083333333333337, 7.1916666666666664, 7.0, 6.1750000000000007, 5.4916666666666663, 5.2583333333333329, 5.6166666666666671, 6.8500000000000005, 7.4916666666666671, 6.9083333333333323, 6.0999999999999988, 5.5916666666666659, 5.4083333333333341, 4.9416666666666673, 4.4999999999999991, 4.2166666666666677, 3.9666666666666663, 4.7416666666666671, 5.7833333333333341, 5.9916666666666671, 5.541666666666667, 5.083333333333333, 4.6083333333333334, 4.6166666666666671, 5.7999999999999998, 9.2833333333333332, 9.6083333333333343, 8.9333333333333336, 8.0749999999999993, 7.3583333333333343, 6.1749999999999998, 5.2666666666666666, 4.8666666666666671, 4.3500000000000005]

# %% [markdown]
# # 我们把坐标延伸到2027年 ,画出图形
# 提示：
# 生成
# uy80years=ny.arange(1948,2028)
# ur80years=ny.arange(80)/20+3
#
# 生成上下界限直线
# ur80yearslow
# ur80yearshigh
#
# 将70年数据给80
# ur80years[0:70]=ur70years

# %%
uy80years=ny.arange(1948,2028)
ur80trend=(ny.arange(80)/23)+4.5
ur80years=(ny.arange(80)/16)

ur80yearslow=(ny.arange(80)/38)+2.8
ur80yearshigh=(ny.arange(80)/18)+6

ur80years[70:72]=ur80years[70:72]+ny.arange(2)*1.2
ur80years[72:80]=ur80years[72:80]-ny.arange(8)*0.5+3


print("NOW print trend after arange 80")
print(ur80trend)


uy70years=ny.array(uy70years)
ur70years=ny.array(ur70years)

ur80years[0:70]=ur70years

print(uy70years)
print(ur70years)

print(uy80years)
print(ur80years)

print(ur80trend)
# Out:
# NOW print trend after arange 80
# [ 4.5         4.54347826  4.58695652  4.63043478  4.67391304  4.7173913
#   4.76086957  4.80434783  4.84782609  4.89130435  4.93478261  4.97826087
#   5.02173913  5.06521739  5.10869565  5.15217391  5.19565217  5.23913043
#   5.2826087   5.32608696  5.36956522  5.41304348  5.45652174  5.5
#   5.54347826  5.58695652  5.63043478  5.67391304  5.7173913   5.76086957
#   5.80434783  5.84782609  5.89130435  5.93478261  5.97826087  6.02173913
#   6.06521739  6.10869565  6.15217391  6.19565217  6.23913043  6.2826087
#   6.32608696  6.36956522  6.41304348  6.45652174  6.5         6.54347826
#   6.58695652  6.63043478  6.67391304  6.7173913   6.76086957  6.80434783
#   6.84782609  6.89130435  6.93478261  6.97826087  7.02173913  7.06521739
#   7.10869565  7.15217391  7.19565217  7.23913043  7.2826087   7.32608696
#   7.36956522  7.41304348  7.45652174  7.5         7.54347826  7.58695652
#   7.63043478  7.67391304  7.7173913   7.76086957  7.80434783  7.84782609
#   7.89130435  7.93478261]
# [1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962
#  1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977
#  1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992
#  1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017]
# [ 3.75        6.05        5.20833333  3.28333333  3.025       2.925
#   5.59166667  4.36666667  4.125       4.3         6.84166667  5.45
#   5.54166667  6.69166667  5.56666667  5.64166667  5.15833333  4.50833333
#   3.79166667  3.84166667  3.55833333  3.49166667  4.98333333  5.95        5.6
#   4.85833333  5.64166667  8.475       7.7         7.05        6.06666667
#   5.85        7.175       7.61666667  9.70833333  9.6         7.50833333
#   7.19166667  7.          6.175       5.49166667  5.25833333  5.61666667
#   6.85        7.49166667  6.90833333  6.1         5.59166667  5.40833333
#   4.94166667  4.5         4.21666667  3.96666667  4.74166667  5.78333333
#   5.99166667  5.54166667  5.08333333  4.60833333  4.61666667  5.8
#   9.28333333  9.60833333  8.93333333  8.075       7.35833333  6.175
#   5.26666667  4.86666667  4.35      ]
# [1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962
#  1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977
#  1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992
#  1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022
#  2023 2024 2025 2026 2027]
# [ 3.75        6.05        5.20833333  3.28333333  3.025       2.925
#   5.59166667  4.36666667  4.125       4.3         6.84166667  5.45
#   5.54166667  6.69166667  5.56666667  5.64166667  5.15833333  4.50833333
#   3.79166667  3.84166667  3.55833333  3.49166667  4.98333333  5.95        5.6
#   4.85833333  5.64166667  8.475       7.7         7.05        6.06666667
#   5.85        7.175       7.61666667  9.70833333  9.6         7.50833333
#   7.19166667  7.          6.175       5.49166667  5.25833333  5.61666667
#   6.85        7.49166667  6.90833333  6.1         5.59166667  5.40833333
#   4.94166667  4.5         4.21666667  3.96666667  4.74166667  5.78333333
#   5.99166667  5.54166667  5.08333333  4.60833333  4.61666667  5.8
#   9.28333333  9.60833333  8.93333333  8.075       7.35833333  6.175
#   5.26666667  4.86666667  4.35        4.375       5.6375      7.5         7.0625
#   6.625       6.1875      5.75        5.3125      4.875       4.4375    ]
# [ 4.5         4.54347826  4.58695652  4.63043478  4.67391304  4.7173913
#   4.76086957  4.80434783  4.84782609  4.89130435  4.93478261  4.97826087
#   5.02173913  5.06521739  5.10869565  5.15217391  5.19565217  5.23913043
#   5.2826087   5.32608696  5.36956522  5.41304348  5.45652174  5.5
#   5.54347826  5.58695652  5.63043478  5.67391304  5.7173913   5.76086957
#   5.80434783  5.84782609  5.89130435  5.93478261  5.97826087  6.02173913
#   6.06521739  6.10869565  6.15217391  6.19565217  6.23913043  6.2826087
#   6.32608696  6.36956522  6.41304348  6.45652174  6.5         6.54347826
#   6.58695652  6.63043478  6.67391304  6.7173913   6.76086957  6.80434783
#   6.84782609  6.89130435  6.93478261  6.97826087  7.02173913  7.06521739
#   7.10869565  7.15217391  7.19565217  7.23913043  7.2826087   7.32608696
#   7.36956522  7.41304348  7.45652174  7.5         7.54347826  7.58695652
#   7.63043478  7.67391304  7.7173913   7.76086957  7.80434783  7.84782609
#   7.89130435  7.93478261]

# %% [markdown]
# # 画出4条曲线
#
# 1.80年预测曲线ur80years
# 2.上限直线ur80yearshigh
# 3.下限直线ur80yearslow
# 4.中间直线ur80trend
#
# 调整合理

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(uy80years,ur80years)
plt.plot(uy80years,ur80trend)
plt.plot(uy80years,ur80yearslow)
plt.plot(uy80years,ur80yearshigh)
plt.plot(uy70years,ur70years)


plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 2025年失业率预计为：

# %%
print(ur80years[77])
print(uy80years[77])
# Out:
# 5.3125
# 2025

# %% [markdown]
# # 仔细看一下我们上大学的那4年的数据

# %%
print(ur80years[70:80])
print(uy80years[70:80])
# Out:
# [ 4.375   5.6375  7.5     7.0625  6.625   6.1875  5.75    5.3125  4.875
#   4.4375]
# [2018 2019 2020 2021 2022 2023 2024 2025 2026 2027]

# %% [markdown]
# # 聚焦今后10年的数据

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(uy80years[70:80],ur80years[70:80])
plt.xticks(rotation=90)
plt.show()
